# %%
#from html.parser import HTMLParser
#from html.entities import name2codepoint
#-*- coding: utf-8 -*-
from bs4 import BeautifulSoup
import requests
import string
import time
import csv
import re
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

url = 'http://www.kft.pwr.edu.pl/people.html'

html_content = requests.get(url).text
soup = BeautifulSoup(html_content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width,initial-scale=1,user-scalable=yes" name="viewport">
#   <title>
#    DTP | Team
#   </title>
#   <!-- CSS -->
#   <link href="css/flexboxgrid.css" rel="stylesheet"/>
#   <link href="css/style.css" rel="stylesheet"/>
#   <link href="css/academicons.min.css" rel="stylesheet">
#    <!-- JS SCRIPTS -->
#    <script crossorigin="anonymous" src="https://kit.fontawesome.com/5a842aaa5f.js">
#    </script>
#    <script src="js/slideshow.js">
#    </script>
#    <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js">
#    </script>
#    <script src="js/smoothscroll.js">
#    </script>
#    <script src="js/to-top.js">
#    </script>
#    <link href="images/WPPT logo.svg" rel="icon" type="image/x-icon"/>
#    <link href="https://fonts.googleapis.com/css2?family=Marcellus&amp;display=swap" rel="stylesheet"/>
# ...

# %%
people = soup.find(id="page")
people
# Out:
# <section class="people" id="page">
# <div class="container">
# <a id="button-to-top"></a>
# <!-- LINKS -->
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 links">
# <a class="button-scroll" href="#OUR-team"> <nobr><i class="fas fa-arrow-alt-circle-down"></i> <b>Our Team</b></nobr></a>
# <a class="button-scroll" href="#PHD-students"> <nobr><i class="fas fa-arrow-alt-circle-down"></i> <b>PhD Students</b></nobr></a>
# <a class="button-scroll" href="#Open-Positions"> <nobr><i class="fas fa-arrow-alt-circle-down"></i> <b>Open Positions</b></nobr></a>
# </div>
# <hr/>
# <!-- HEAD OF DIVISION -->
# <div class="row center-xs center-sm center-md center-lg middle-xs middle-sm middle-md middle-lg">
# <!-- Poczatek czÅowieka -->
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-5 ludzik">
# <div class="row center-xs center-sm center-md center-lg middle-xs middle-sm middle-md middle-lg wizytowki" id="KatarzynaWeron">
# <div class="col-xs-12 col-sm-12 col-md-12 col-lg-12 kolumna">
# ...

# %%
names = people.find_all("h4")
names
# Out:
# [<h4>Prof. dr hab. Katarzyna <nobr>Sznajd-Weron</nobr></h4>,
#  <h4>Dr hab. inÅ¼. Andrzej Janutka, prof. PWr</h4>,
#  <h4>Dr Maciej Bieniek</h4>,
#  <h4>Dr inÅ¼. Liliana Bujkiewicz</h4>,
#  <h4>Dr Marta BrzeziÅska</h4>,
#  <h4>Dr inÅ¼. Krzysztof Gawarecki</h4>,
#  <h4>Dr inÅ¼. MichaÅ GaweÅczyk</h4>,
#  <h4>Dr inÅ¼. Anna Hajdusianek, prof. PWr</h4>,
#  <h4>Dr Jacek Herbrych</h4>,
#  <h4>Dr Arkadiusz JÄdrzejewski</h4>,
#  <h4>Dr inÅ¼. PaweÅ Karwat</h4>,
#  <h4>Prof. dr hab. inÅ¼. Marek Klonowski</h4>,
#  <h4>Dr Piotr Kowalski</h4>,
#  <h4>Dr MaÅgorzata Kuchta</h4>,
#  <h4>Dr Adrian Lewandowski</h4>,
#  <h4>Dr inÅ¼. Patrycja ÅydÅ¼ba</h4>,
#  <h4>Prof. dr hab. inÅ¼. PaweÅ Machnikowski</h4>,
#  <h4>Dr Jan Major</h4>,
#  <h4>Prof. dr hab. Maciej MaÅka</h4>,
#  <h4>Dr Adam <nobr>Mielnik-Pyszczorski</nobr></h4>,
#  <h4>Prof. dr hab. Marcin Mierzejewski</h4>,
#  <h4>Prof. dr hab. Antoni MituÅ</h4>,
#  <h4>Prof. dr hab. MichaÅ Morayne</h4>,
#  <h4>Dr Maciej Mulak</h4>,
# ...

# %%
researchers = []
for name in names:
    researcher = name.text
    researchers.append(researcher)
researchers_plain = []
for researcher in researchers:
    table = researcher.maketrans(dict.fromkeys(string.punctuation))
    no_pointers = researcher.translate(table)
    researchers_plain.append(no_pointers)
print(researchers_plain)
# Out:
# ['Prof dr hab Katarzyna SznajdWeron', 'Dr hab inÅ¼ Andrzej Janutka prof PWr', 'Dr Maciej Bieniek', 'Dr inÅ¼ Liliana Bujkiewicz', 'Dr Marta BrzeziÅ\x84ska', 'Dr inÅ¼ Krzysztof Gawarecki', 'Dr inÅ¼ MichaÅ\x82 GaweÅ\x82czyk', 'Dr inÅ¼ Anna Hajdusianek prof PWr', 'Dr Jacek Herbrych', 'Dr Arkadiusz JÄ\x99drzejewski', 'Dr inÅ¼ PaweÅ\x82 Karwat', 'Prof dr hab inÅ¼ Marek Klonowski', 'Dr Piotr Kowalski', 'Dr MaÅ\x82gorzata Kuchta', 'Dr Adrian Lewandowski', 'Dr inÅ¼ Patrycja Å\x81ydÅ¼ba', 'Prof dr hab inÅ¼ PaweÅ\x82 Machnikowski', 'Dr Jan Major', 'Prof dr hab Maciej MaÅ\x9bka', 'Dr Adam MielnikPyszczorski', 'Prof dr hab Marcin Mierzejewski', 'Prof dr hab Antoni MituÅ\x9b', 'Prof dr hab MichaÅ\x82 Morayne', 'Dr Maciej Mulak', 'Dr Wojciech Mulak', 'Dr hab Wojciech Mydlarczyk prof PWr', 'Dr hab inÅ¼ Grzegorz Pawlik prof PWr', 'Dr inÅ¼ JarosÅ\x82aw PawÅ\x82owski', 'Dr Wojciech Radosz', 'Dr hab inÅ¼ Katarzyna Roszak prof PWr', 'Dr Adam Sajna', 'Dr hab inÅ¼ Anna Sitek prof PWr', 'Dr Piotr SurÃ³wka',
# ...

# %%
for researcher in researchers_plain:
    surname = ''
    for word in researcher:
        surname = word
    print(surname)
# Out:
# n
# r
# k
# z
# a
# i
# k
# r
# h
# i
# t
# i
# i
# a
# i
# a
# i
# r
# a
# i
# i
# 
# e
# k
# k
# r
# r
# i
# z
# r
# a
# r
# a
# l
# r
# s
# j
# k
# y
# l
# n
# a
# i
# i
# z
# k
# i
# a

# %%
df = pd.read_csv("scopus.csv")
#df = df.loc[df['weight']>10, :]
df1 = df[['Authors','Title']]
df1
